# %% [markdown]
# # 01 — NHANES 2017-2018 Data Download & Merge
#
# Downloads the 10 required NHANES components and merges them on `SEQN`.
#
# **Note:** requires general internet access to `wwwn.cdc.gov`. If running in a network-restricted environment, run this notebook locally or in Colab instead.

# %%
import sys, yaml
sys.path.append('../src')
from data_loader import load_config, download_and_merge, save_merged

config = load_config('../config.yaml')
config
# Out:
# {'random_seed': 42,
#  'nhanes': {'cycle': '2017-2018',
#   'suffix': 'J',
#   'base_url': 'https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/',
#   'files': {'DEMO_J': 'Demographics',
#    'BMX_J': 'Body Measurements',
#    'BPX_J': 'Blood Pressure',
#    'GLU_J': 'Fasting Glucose',
#    'GHB_J': 'Glycohemoglobin (HbA1c)',
#    'HDL_J': 'HDL Cholesterol',
#    'TCHOL_J': 'Total Cholesterol',
#    'TRIGLY_J': 'Triglycerides & LDL (includes fasting insulin)',
#    'PAQ_J': 'Physical Activity Questionnaire',
#    'DIQ_J': 'Diabetes Questionnaire'},
#   'merge_key': 'SEQN'},
#  'paths': {'raw_dir': 'data/raw',
#   'processed_dir': 'data/processed',
#   'merged_csv': 'data/processed/nhanes_merged_2017_2018.csv',
#   'model_dir': 'models',
#   'figures_dir': 'outputs/figures',
#   'reports_dir': 'outputs/reports'},
#  'preprocessing': {'missing_value_drop_threshold': 0.4,
#   'outlier_method': 'iqr',
#   'zscore_threshold': 3.0,
#   'iqr_multiplier': 1.5,
#   'correlation_drop_threshold': 0.9,
# ...

# %%
merged_df = download_and_merge(config)
merged_df.shape
# Out:
# 2026-07-11 18:07:35,840 | INFO | data_loader | Downloading https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.XPT -> data/raw\DEMO_J.XPT
# 2026-07-11 18:07:37,019 | INFO | data_loader | Reading data/raw\DEMO_J.XPT
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 merged_df = download_and_merge(config)
#       2 merged_df.shape
#
# File c:\Users\asmak\Downloads\rmr_prediction_project\rmr_prediction_project\notebooks\../src\data_loader.py:115, in download_and_merge(config)
#     113 for stub in file_stubs:
#     114     local_path = download_xpt(stub, base_url, raw_dir)
# --> 115     df = read_xpt(local_path)
#     116     component_shapes[stub] = df.shape
#     118     if merged_df is None:
#
# File c:\Users\asmak\Downloads\rmr_prediction_project\rmr_prediction_project\notebooks\../src\data_loader.py:91, in read_xpt(local_path)
# ...

# %%
merged_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 merged_df.head()
#
# NameError: name 'merged_df' is not defined

# %%
save_merged(merged_df, config)
